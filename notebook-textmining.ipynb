# %% [markdown]
# # O QUE É CIÊNCIA?
#
# 1. Conjunto de métodos para adquirir conhecimento.
# 2. Inicia-se com um processo observação
# 3. Thomas Bayes: The doctrine of fluxions ( A doutrina dos fluxions )
#
# https://cienciahoje.org.br/artigo/thomas-bayes-o-cara/
#
# "Com base nesse livro e em outras possíveis contribuições sobre as quais não temos dados precisos, Bayes foi eleito em 1752 para a Royal Society, sociedade científica britânica criada em 1645. Dois anos após sua morte, um amigo, o filósofo Richard Price (1723-1791), apresentou à Royal Society um artigo que aparentemente encontrou entre os papéis do reverendo, com o nome ‘ An essay towards solving a problem in the doctrine of chances ’ (‘Ensaio buscando resolver um problema na doutrina das probabilidades’). Nesse artigo estava a demonstração do famoso teorema de Bayes. Price acreditava que o artigo fornecia uma prova da existência de Deus ( clique aqui para baixar o texto na íntegra). Após sua publicação, o trabalho caiu no esquecimento, do qual só foi resgatado pelo matemático francês Pierre-Simon de Laplace (1749-1827), que o revelou ao mundo."
#
#
# **Como é o teorema de bayes. Eu quero a fórmula detalhada
#  passo a passo.
# Eu sou um estudante iniciante em inteligência artificial.
# Não sou programador nem matemático nem estátistico .
# Pegue leve, use exemplos do dia a dia.**
#
#
#
# Claro! Vou explicar o **Teorema de Bayes** de forma acessível, com exemplos do dia a dia. Como você mencionou que é um estudante iniciante em inteligência artificial, vou simplificar o conceito e evitar jargões técnicos. 😊
#
# O **Teorema de Bayes** é uma ferramenta poderosa para calcular probabilidades condicionais. Ele nos permite atualizar nossas estimativas de probabilidade com base em novas evidências. Vamos dar uma olhada na fórmula e depois aplicá-la a um exemplo prático.
#
# ### Fórmula do Teorema de Bayes
#
# Aqui está a fórmula do Teorema de Bayes:
#
# $$ P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)} $$
#
# Aqui estão os significados das variáveis:
# - \(P(A|B)\): Probabilidade do evento \(A\) ocorrer, dado que o evento \(B\) já aconteceu.
# - \(P(B|A)\): Probabilidade do evento \(B\) acontecer, dado que o evento \(A\) já ocorreu.
# - \(P(A)\): Probabilidade do evento \(A\) ocorrer (antes de considerar qualquer nova evidência).
# - \(P(B)\): Probabilidade do evento \(B\) acontecer (antes de considerar qualquer nova evidência).
#
# ### Exemplo com Bolas Vermelhas e Azuis
#
# Vamos usar um exemplo simples com bolas vermelhas e azuis em uma caixa. Imagine que temos uma caixa com duas bolas vermelhas e três bolas azuis. Vamos retirar duas bolas ao acaso, uma após a outra, sem reposição.
#
# 1. Qual é a probabilidade de a **segunda bola** (evento \(B\)) ser **vermelha**, considerando que a **primeira bola** (evento \(A\)) foi **azul**?
# 2. Qual é a probabilidade de a **primeira bola** (evento \(A\)) ser **azul**, considerando que a **segunda bola** (evento \(B\)) será **vermelha**?
#
# Vamos calcular:
#
# 1. Primeiro, usamos a **probabilidade condicional** para encontrar \(P(B|A)\):
#    - A probabilidade de a segunda bola ser vermelha, dado que a primeira foi azul, é \(\frac{1}{2}\) (pois só sobram duas bolas vermelhas e três azuis).
# 2. Agora, aplicamos o **Teorema de Bayes** para encontrar \(P(A|B)\):
#    - \(P(A) = \frac{3}{5}\) (probabilidade inicial de pegar uma bola azul).
#    - \(P(B) = \frac{1}{2}\) (probabilidade inicial de pegar uma bola vermelha).
#    - \(P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)} = \frac{\frac{1}{2} \cdot \frac{3}{5}}{\frac{1}{2}} = \frac{3}{5}\).
#
# Portanto, a probabilidade de a primeira bola ser azul, dado que a segunda bola será vermelha, é \(\frac{3}{5}\).
#
# Espero que isso tenha ajudado! O Teorema de Bayes é uma ferramenta fundamental em estatística e inteligência artificial, e entender seus conceitos básicos é um ótimo começo. Se tiver mais perguntas, estou à disposição! 😊
#
# ⁴: [Suno - Teorema de Bayes: Entenda o que é e como calcular](https://www.suno.com.br/artigos/teorema-de-bayes/)
# ⁵: [Greelane.com - Bayes' Theorem](https://www.greelane.com/pt/ci%C3%AAncia-tecnologia-matem%C3%A1tica/matem%C3%A1tica/bayes-theorem-4155845/)
# ⁹: [Wikipédia - Teorema de Bayes](https://pt.wikipedia.org/wiki/Teorema_de_Bayes)
#
# Fonte: conversa com o Copilot, 03/06/2024
# (1) Teorema de Bayes: Entenda o que é e como calcular - Suno. https://www.suno.com.br/artigos/teorema-de-bayes/.
# (2) Definição e Exemplos do Teorema de Bayes - Greelane.com. https://www.greelane.com/pt/ci%C3%AAncia-tecnologia-matem%C3%A1tica/matem%C3%A1tica/bayes-theorem-4155845/.
# (3) Teorema de Bayes – Wikipédia, a enciclopédia livre. https://pt.wikipedia.org/wiki/Teorema_de_Bayes.
# (4) TEOREMA DE BAYES | Cálculo de Probabilidade | Responde Aí. https://www.youtube.com/watch?v=goaRH7a5hR4.
# (5) Probabilidade Aula 12 - Teorema de Bayes. https://www.youtube.com/watch?v=dWdyxWQrxAY.
# (6) Entenda o Teorema de Bayes (ótima explicação!). https://www.youtube.com/watch?v=I643PqSrETM.
# (7) TEOREMA DE BAYES: APRENDA O QUE É E SAIBA COMO CALCULAR. https://www.hminvest.com.br/post/teorema-de-bayes-aprenda-o-que-%C3%A9-e-saiba-como-calcular.
# (8) Teorema de Bayes | Introducción. https://www.youtube.com/watch?v=bDfCURXoKkU.
# (9) Teorema de Bayes | Ejemplo 1. https://www.youtube.com/watch?v=NdcpLrFd2RM.
# (10) Teorema de Bayes: saiba o que é, aplicações e exemplos - Voitto. https://www.voitto.com.br/blog/artigo/teorema-de-bayes.

# %% [markdown]
# # GPT
#
# 1.  Inteligência Artificial Generativa
# - Texto que gera texto
# - Texto que gera imagem
# - Texto que gera vídeo
# - Testo que gera audio
#
#
# 2. PLN ( Processamento de linguagem natutal)
#
#
# - Mineração de texto em documentos
# - Estudio de docmuneto inteligência
#
# # ChatBots
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mineração de Textos em Documentos
#
# - Laboratório: Ler palavras dentro de uma imagem
# 1. Entrar  no Estudio de Documento inteligente
#  - Azure Document Intelligence Studio
#  - Inteligência de Documentos se baseia no reconhecimento óptico de caracteres (OCR)
#
#  ![image.png](attachment:image.png)
